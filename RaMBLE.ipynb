# %% [markdown]
# Setup globals

# %%
import datetime
import pandas as pd
import sqlite3
import time

day_of_seconds = 86400
week_of_seconds = 7 * day_of_seconds
month_of_seconds = 30 * day_of_seconds

today = int(time.mktime(datetime.date.today().timetuple()))

# %% [markdown]
# The following cell values are safe to modify as needed

# %%
sqlite_file = 'RaMBLE.sqlite'
max_rows = 500

# Typically only looking back the past week
wayback = today-week_of_seconds

# %% [markdown]
# Pull in database

# %%
pd.set_option('display.max_rows', max_rows)
db = sqlite3.connect(sqlite_file)
new_devices = pd.read_sql_query("SELECT * from devices WHERE first_seen >= %d" % (wayback), db)
old_devices = pd.read_sql_query("SELECT * from devices WHERE first_seen < %d" % (wayback), db)

# %% [markdown]
# The database has two important tables: `devices` and `locations`, but this notebook will only be focusing on `devices`.
#
# devices
# * id (int)
# * address (string: OUI)
# * adv_flags (float)
# * device_name (string)
# * device_type (string)
# * first_seen (int)
# * last_seen (int)
# * msd_key (float, Manufacturer Data: ID)
# * msd_field (hex string, Manufacturer Data: Data)
# * service_uuids (string uuid)
# * service_data (string hex data)
# * days_seen (int)
# * raw_adv_data (bitstring)
#
# locations
# * id (int)
# * device_id (int)
# * timestamp (int)
# * rssi (int)
# * tx_power (float)
# * latitude (float)
# * logitude (float)
# * accuracy (float)
# * packets_received (int)

# %% [markdown]
# # New Devices

# %%
print(f"{old_devices.id.count()} devices from {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(old_devices.iloc[0].first_seen))} to {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(old_devices.iloc[-1].first_seen))}")
print(f"{new_devices.id.count()} devices from {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(new_devices.iloc[0].first_seen))} to {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(new_devices.iloc[-1].first_seen))}")
# Out:
# 10545 devices from 2018-11-20 15:12:37 to 2020-03-13 17:39:36
# 1156 devices from 2020-08-31 18:06:10 to 2020-09-05 13:31:39

# %% [markdown]
# ## New Device Names

# %%
old_names = old_devices['device_name'].dropna(how='any').unique()

new_names = new_devices.copy()
for old_name in old_names:
    new_names = new_names[new_names.device_name != old_name]

name_count = pd.DataFrame(new_names.device_name.value_counts()).sort_index()

device_report = list()

for new_name in name_count.index:
    new_device = new_devices[new_devices.device_name == new_name]
    
    for device in new_device.index:
        device_report.append(new_device.loc[device, ["device_name", "device_type", "address", "service_uuids"]].values)

device_name_report = pd.DataFrame(device_report)
device_name_report.columns = ["device_name", "device_type", "address", "service_uuids"]

# %%
name_count
# Out:
#                             device_name
# 00A05020BEF01B28z22                   1
# 00A05020E1A50D200T0                   1
# 00A05020E1B20028z02                   1
# ALAM (24:F7:2C)                      1
# BLE-OHL-01                            1
# BLE_08A0                              1
# BLE_891B                              1
# BLE_92EB                              1
# BLE_C826                              1
# BLE_E586                              1
# C-by-GE-D238D755                      1
# CB833CAE8D48                          1
# CCGB617400320                         1
# CCJB618380306                         1
# DCS-8525LH-4270                       1
# DV7200-4.0-382C                       1
# Dispatch TV                           1
# Dual iPlug                            2
# ELK-BLEDOM                            4
# Forerunner 25                        1
# G-519C9C                              1
# Galaxy Watch (656E) LE                1
# I_TL                                  1
# IronSoulCast                          1
# JBL Flip 3                            1
# LCIRemoteNwBKfKvbV                    1
# LE-Bose SoundSport Free               1
# LG CJ45  (70)                         1
# LG CJ45  (83)                         1
# LG CJ45  (F1)                         1
# LG SH4(6F)                            1
# LG SH4(72)                            1
# MSH317_Ble_C7A                        1
# MediaPlayer-830761                    1
# Mercury                               1
# Micro Mechanic                        1
# Office speaker                        4
# PDSCB110                              1
# PayPal-10395335                       1
# QHM-0CAE                              1
# RN456D                                1
# SpinTouch-061623                      1
# Tag-It                                1
# VM-207-BLE                            1
# XY4+                                  1
# [LG] webOS TV UJ6540                  2
# [TV] Samsung 6 Series (40)            1
# [TV] UN40JU6500                       1
# [TV] UN50JU6500                       1
# [TV] UN65J6300                        1
# iHome iBTW39 app                      1
# iRadar                                1
# ihoment_H6105_6675                    1
# ihoment_H6114_7902                    1

# %%
device_name_report.sort_values(by="address")
# Out:
#                    device_name                             device_type  \
# 0          00A05020BEF01B28z22                         Battery Service
# 2          00A05020E1B20028z02                         Battery Service
# 24                    G-519C9C                                    None
# 39              Micro Mechanic                                    None
# 45             PayPal-10395335                                    None
# 36              MSH317_Ble_C7A                       CUBE TECHNOLOGIES
# 1          00A05020E1A50D200T0                         Battery Service
# 47                      RN456D                                    None
# 31               LG CJ45  (70)                          LG Electronics
# 33               LG CJ45  (F1)                          LG Electronics
# 32               LG CJ45  (83)                          LG Electronics
# 35                  LG SH4(72)                          LG Electronics
# 34                  LG SH4(6F)                          LG Electronics
# 38                     Mercury                                    None
# 17                  Dual iPlug                                    None
# 18                  Dual iPlug                                    None
# 52        [LG] webOS TV UJ6540                          LG Electronics
# 30     LE-Bose SoundSport Free                                    Bose
# 42              Office speaker                                  Google
# 40              Office speaker                                  Google
# 43              Office speaker                                  Google
# 41              Office speaker                                  Google
# 53        [LG] webOS TV UJ6540                          LG Electronics
# 50                  VM-207-BLE                  Human Interface Device
# 16                 Dispatch TV                                  Google
# 4                   BLE-OHL-01                  Human Interface Device
# 57              [TV] UN65J6300  Smart TV, Samsung, Samsung Electronics
# 27                IronSoulCast                                  Google
# 37          MediaPlayer-830761                                    None
# 10            C-by-GE-D238D755                    Telink Semiconductor
# 11                CB833CAE8D48                    Telink Semiconductor
# 61          ihoment_H6114_7902                                    None
# 60          ihoment_H6105_6675                                    None
# 46                    QHM-0CAE                                    None
# 14             DCS-8525LH-4270                                    None
# 3             ALAM (24:F7:2C)                                    None
# 28                  JBL Flip 3         Harman International Industries
# 48            SpinTouch-061623                                    None
# 22                 ELK-BLEDOM                                     None
# 21                 ELK-BLEDOM                                     None
# 20                 ELK-BLEDOM                                     None
# 19                 ELK-BLEDOM                                     None
# 15             DV7200-4.0-382C                                    None
# 23              Forerunner 25                                  Garmin
# 44                    PDSCB110                                    None
# 59                      iRadar                        nRF UART Service
# 12               CCGB617400320                                 ORBCOMM
# 13               CCJB618380306                                 ORBCOMM
# 26                        I_TL                 Icon Health and Fitness
# 54  [TV] Samsung 6 Series (40)           Smart TV, Samsung Electronics
# 51                        XY4+           iBeacon, Dialog Semiconductor
# 25      Galaxy Watch (656E) LE                     Samsung Electronics
# 29          LCIRemoteNwBKfKvbV                      Lippert Components
# 9                     BLE_E586           Ericsson Technology Licensing
# 54  E4:7D:BD:24:AF:4C                                       None
# 51  E9:12:1D:F1:C3:0E  fef5,e8d84b30-785f-0000-0000-0401f4ac4ea4
# 25  EC:00:D6:3A:0A:DC                                       None
# 29  F3:FE:46:53:CA:8F       00000000-0200-a58e-e411-afe28044e62c
# 9   F6:3B:01:6B:E5:86                                       6666
# 7   F6:3B:01:7D:92:EB                                       6666
# 6   F6:3B:01:A4:89:1B                                       6666
# 5   F6:3B:01:A8:08:A0                                       6666
# 8   F6:3B:02:EE:C8:26                                       6666
# 58  F7:EB:ED:DF:4E:91                                       0000
# 56  F8:04:2E:88:04:4F                                       None
# 55  F8:04:2E:96:14:4F                                       None
# 49  FF:FF:00:04:1C:16                                       ffe0

# %% [markdown]
# ## New Device Types

# %%
old_types = old_devices['device_type'].dropna(how='any').sort_values().unique()
new_types = new_devices.copy()

for old_type in list(old_types):
    new_types = new_types[new_types.device_type != old_type]

type_count = pd.DataFrame(new_types.device_type.value_counts()).sort_index()

device_report = list()

for new_type in type_count.index:
    new_device = new_devices[new_devices.device_type == new_type]
    
    for device in new_device.index:
        device_report.append(new_device.loc[device, ["device_name", "device_type", "address", "service_uuids"]].values)

device_type_report = pd.DataFrame(device_report)
device_type_report.columns = ["device_name", "device_type", "address", "service_uuids"]

# %%
type_count
# Out:
#                                                     device_type
# Apple, Wireless Audio                                         4
# Bose                                                          3
# Bose, SGL Italia                                              2
# CSR                                                           1
# CUBE TECHNOLOGIES                                             3
# Device Information                                            6
# Device Information, Fitbit                                    1
# Eddystone UID beacon                                          1
# Eddystone URL beacon - http://mrefer.com/415323...            1
# Exposure Notification                                         1
# Fitbit Charge, Device Information, Fitbit                     1
# Google, Chromecast                                           30
# Hewlett-Packard Company, HP                                  11
# Icon Health and Fitness                                       1
# Lippert Components                                            1
# ORBCOMM                                                       2
# Sony                                                          2
# iBeacon, Dialog Semiconductor                                 1
# iBeacon, Eddystone URL beacon - http://mrefer.c...            1

# %%
device_type_report.sort_values(by="address")
# Out:
#                    device_name  \
# 12              MSH317_Ble_C7A
# 58                        None
# 60                        None
# 57                        None
# 8   LE-Bose Color II SoundLink
# 7   LE-Bose Color II SoundLink
# 22                        None
# 62                        None
# 25                        None
# 47                        None
# 43                        None
# 30                        None
# 69                        None
# 41                        None
# 42                        None
# 4      LE-Bose Free SoundSport
# 5                LE-reserved_C
# 6      LE-Bose SoundSport Free
# 49                        None
# 46                        None
# 39                        None
# 40                        None
# 44                        None
# 3                         None
# 29                        None
# 36                        None
# 28                        None
# 20                        None
# 31                        None
# 38                        None
# 37                        None
# 26                        None
# 33                        None
# 32                        None
# 34                        None
# 35                        None
# 70                        None
# 45                        None
# 2                         None
# 51                        None
# 50                        None
# 48                        None
# 24                        None
# 1                         None
# 27                        None
# 52                        None
# 53                        None
# 63                        None
# 55                        None
# 0                         None
# 54                        None
# 64                        None
# 17                     Versa 2
# 9                         None
# 21                        None
# 23                    Charge 3
# 67               CCGB617400320
# 18                     Versa 2
# 68               CCJB618380306
# 65                        I_TL
# 72                        None
# 56                        None
# 61                        None
# 71                        XY4+
# 14                     Versa 2
# 66          LCIRemoteNwBKfKvbV
# 11                    BLE_08A0
# 10            iHome iBTW39 app
# 19                  Inspire HR
# 16                  Versa Lite
# 13                     Versa 2
# 59                        None
# 15                     Versa 2
#
#                                           device_type            address  \
# 12                                  CUBE TECHNOLOGIES  00:22:6C:D6:8C:7B
# 58                        Hewlett-Packard Company, HP  00:68:EB:FB:22:E3
# 60                        Hewlett-Packard Company, HP  02:68:EB:45:2C:20
# 57                        Hewlett-Packard Company, HP  02:68:EB:46:80:9B
# 8                                    Bose, SGL Italia  28:11:A5:AB:12:E5
# 7                                    Bose, SGL Italia  2C:41:A1:CC:30:E6
# 22                              Exposure Notification  35:BE:AB:BF:94:69
# 62                        Hewlett-Packard Company, HP  3A:22:E2:9E:58:99
# 25                                 Google, Chromecast  40:E2:B3:BD:6B:08
# 47                                 Google, Chromecast  42:7F:61:FD:D2:80
# 43                                 Google, Chromecast  43:83:C3:5A:B3:0A
# 30                                 Google, Chromecast  44:52:F9:C6:9D:46
# 69                                               Sony  48:E2:44:74:7D:A6
# 41                                 Google, Chromecast  4A:67:11:CA:8D:D1
# 42                                 Google, Chromecast  4B:5F:55:60:9D:AE
# 4                                                Bose  4C:87:5D:18:59:34
# 5                                                Bose  4C:87:5D:18:7A:F8
# 6                                                Bose  4C:87:5D:63:AB:25
# 49                                 Google, Chromecast  51:67:FC:E1:8A:F6
# 46                                 Google, Chromecast  51:91:11:FE:13:A5
# 39                                 Google, Chromecast  52:74:7A:28:8B:32
# 40                                 Google, Chromecast  54:E8:10:68:55:9F
# 44                                 Google, Chromecast  56:00:4B:10:7E:30
# 3                               Apple, Wireless Audio  57:5C:A7:82:2F:9F
# 29                                 Google, Chromecast  57:E6:FE:4F:BC:79
# 36                                 Google, Chromecast  59:84:6A:F0:6C:7B
# 28                                 Google, Chromecast  5A:AB:C1:78:14:63
# 20                               Eddystone UID beacon  5C:5B:35:8E:6F:7F
# 31                                 Google, Chromecast  5E:92:F4:52:7C:72
# 38                                 Google, Chromecast  60:3F:10:43:C9:47
# 37                                 Google, Chromecast  61:A4:66:87:DC:E9
# 26                                 Google, Chromecast  61:C6:35:F3:DC:FA
# 33                                 Google, Chromecast  6B:2F:BA:30:BA:AA
# 32                                 Google, Chromecast  6D:C1:F7:33:CF:DB
# 34                                 Google, Chromecast  6F:DE:E6:DF:1D:C2
# 35                                 Google, Chromecast  70:37:B4:AA:D7:9C
# 70                                               Sony  70:77:81:AB:9D:C2
# 45                                 Google, Chromecast  71:B2:B3:68:23:54
# 2                               Apple, Wireless Audio  73:17:6E:DC:5B:9A
# 51                                 Google, Chromecast  73:2D:9D:B8:B8:A4
# 50                                 Google, Chromecast  74:C8:36:8E:2B:BA
# 48                                 Google, Chromecast  77:8E:52:B7:70:80
# 24                                 Google, Chromecast  7C:21:8F:63:18:B1
# 1                               Apple, Wireless Audio  7C:EF:8E:D1:AF:8B
# 27                                 Google, Chromecast  7E:56:82:5E:53:C8
# 52                                 Google, Chromecast  7E:72:14:97:B0:47
# 53                                 Google, Chromecast  7F:3A:38:C0:AE:44
# 63                        Hewlett-Packard Company, HP  82:E8:2C:60:CA:E2
# 55                        Hewlett-Packard Company, HP  82:E8:2C:A9:0E:48
# 0                               Apple, Wireless Audio  91:10:92:00:80:A3
# 54                        Hewlett-Packard Company, HP  B0:5C:DA:CA:47:4F
# 64                        Hewlett-Packard Company, HP  BE:E9:2F:AD:68:E7
# 17                                 Device Information  C1:5C:EE:D8:09:F4
# 9                                                 CSR  C1:E9:B6:00:1C:DB
# 21  Eddystone URL beacon - http://mrefer.com/41532...  C7:4E:77:81:86:0F
# 23          Fitbit Charge, Device Information, Fitbit  D2:A2:EE:B2:59:51
# 67                                            ORBCOMM  D3:26:08:B5:F0:61
# 18                                 Device Information  D3:E3:0A:A0:63:F6
# 68                                            ORBCOMM  D6:65:3A:EC:36:BF
# 65                            Icon Health and Fitness  DA:5D:5A:48:68:17
# 72  iBeacon, Eddystone URL beacon - http://mrefer....  E2:7A:82:7A:9E:DF
# 56                        Hewlett-Packard Company, HP  E6:E7:49:B5:FC:C7
# 61                        Hewlett-Packard Company, HP  E6:E7:49:B7:BA:4D
# 71                      iBeacon, Dialog Semiconductor  E9:12:1D:F1:C3:0E
# 14                                 Device Information  E9:25:51:05:F6:F9
# 66                                 Lippert Components  F3:FE:46:53:CA:8F
# 11                                  CUBE TECHNOLOGIES  F6:3B:01:A8:08:A0
# 10                                  CUBE TECHNOLOGIES  F7:EB:ED:DF:4E:91
# 19                         Device Information, Fitbit  F9:3E:98:3A:4E:E8
# 16                                 Device Information  F9:6B:56:44:A8:D8
# 13                                 Device Information  F9:E7:F6:99:57:FF
# 59                        Hewlett-Packard Company, HP  FA:B4:6A:82:34:D3
# 15                                 Device Information  FA:DA:72:71:6F:ED
#
#                                 service_uuids
# 12                                  ffc0,6666
# 58                                       fe78
# 60                                       fe78
# 57                                       fe78
# 8                                        febe
# 7                                        febe
# 22                                       fd6f
# 62                                       fe78
# 25                                       fe9f
# 47                                       fe9f
# 43                                       fe9f
# 30                                       fe9f
# 69                                       None
# 41                                       fe9f
# 42                                       fe9f
# 4                                        febe
# 5                                        febe
# 6                                        febe
# 49                                       fe9f
# 46                                       fe9f
# 39                                       fe9f
# 40                                       fe9f
# 44                                       fe9f
# 3                                        None
# 29                                       fe9f
# 36                                       fe9f
# 28                                       fe9f
# 20                                       feaa
# 31                                       fe9f
# 38                                       fe9f
# 37                                       fe9f
# 26                                       fe9f
# 33                                       fe9f
# 32                                       fe9f
# 34                                       fe9f
# 35                                       fe9f
# 70                                       None
# 45                                       fe9f
# 2                                        None
# 51                                       fe9f
# 50                                       fe9f
# 48                                       fe9f
# 24                                       fe9f
# 1                                        None
# 27                                       fe9f
# 52                                       fe9f
# 53                                       fe9f
# 63                                       fe78
# 55                                       fe78
# 0                                        None
# 54                                       fe78
# 64                                       fe78
# 17       abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 9                                        None
# 21                                       feaa
# 23       adabfb00-6e7d-4601-bda2-bffaa68956ba
# 67                                       None
# 18       abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 68                                       None
# 65       00001533-1412-efde-1523-785feabcd123
# 72  feaa,1786b941-062b-17b7-4df6-3f79361ad91f
# 56                                       fe78
# 61                                       fe78
# 71  fef5,e8d84b30-785f-0000-0000-0401f4ac4ea4
# 14       abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 66       00000000-0200-a58e-e411-afe28044e62c
# 11                                       6666
# 10                                       0000
# 19       adabfb00-6e7d-4601-bda2-bffaa68956ba
# 16       abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 13       abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 59                                       fe78
# 15       abbaff00-e56a-484c-b832-8b17cf6cbfe8

# %% [markdown]
# ## New OUIs

# %%
old_ouis = list()
new_ouis = list()
new_addresses = list()

for old_address in old_devices['address']:
    oui_octets = old_address.split(':')[:3]
    
    # check to see if this is a global oui
    if int(oui_octets[0], 16) & 0x2 == 0:
        #turn off the multicast bit
        oui_octets[0] = '{:02x}'.format(int(oui_octets[0], 16) & 0xe)
        old_ouis.append(':'.join(oui_octets))

for new_address in new_devices['address']:
    oui_octets = new_address.split(':')[:3]
    
    # check to see if this is a global oui
    if int(oui_octets[0], 16) & 0x3 > 0:
        continue
    
    #turn off the multicast bit
    oui_octets[0] = '{:02x}'.format(int(oui_octets[0], 16) & 0xe)
    new_oui = ':'.join(oui_octets)
    
    if new_oui not in old_ouis:
        new_ouis.append(new_oui)
        new_addresses.append(new_address)

device_report = list()

for new_address in new_addresses:
    new_device = new_devices[new_devices.address == new_address]
    
    for device in new_device.index:
        device_report.append(new_device.loc[device, ["device_name", "device_type", "address", "service_uuids"]].values)

device_oui_report = pd.DataFrame(device_report)
device_oui_report.columns = ["device_name", "device_type", "address", "service_uuids"]

# %%
pd.DataFrame(pd.Series(new_ouis).value_counts())
# Out:
#           0
# 04:FE:FB  3
# 08:27:37  3
# 00:01:AD  2
# 04:5C:E9  2
# 08:6F:8E  1
# 08:BC:89  1
# 00:34:F5  1
# 04:77:5F  1
# 04:2A:80  1
# 08:E2:44  1
# 04:DE:99  1
# 04:F0:61  1
# 04:32:A1  1
# 04:37:28  1
# 0c:93:92  1
# 04:B7:9E  1
# 0c:82:2E  1
# 00:EA:CE  1
# 0c:7B:2A  1
# 00:23:43  1
# 04:60:1B  1
# 04:71:18  1
# 08:20:3D  1
# 00:68:EB  1
# 00:CB:E3  1
# 00:2A:D1  1
# 00:37:B4  1
# 0c:54:C5  1
# 08:44:62  1
# 08:F5:CE  1
# 04:21:CB  1
# 08:07:FF  1
# 04:4A:C4  1
# 08:BC:11  1
# 0c:D2:81  1
# 0c:8F:D5  1
# 0c:58:B6  1
# 0c:46:80  1
# 04:9E:D3  1
# 0c:21:8F  1
# 04:9D:D2  1
# 0c:26:4D  1
# 08:F0:A3  1
# 08:68:AD  1
# 00:B5:78  1
# 00:7A:A6  1
# 04:A1:07  1
# 0c:D0:13  1
# 08:0F:DE  1
# 0c:61:4C  1
# 00:3E:28  1
# 00:6D:1C  1
# 00:3C:E5  1
# 04:6F:69  1
# 0c:BC:05  1
# 04:E4:5E  1
# 08:5F:8D  1
# 00:94:7B  1
# 04:7D:D4  1
# 00:EB:D1  1
# 04:C8:36  1
# 00:42:4E  1
# 0c:2E:C5  1
# 08:69:18  1
# 00:05:C2  1
# 08:01:F2  1
# 00:61:E6  1
# 08:A8:76  1
# 0c:17:28  1
# 00:3D:C5  1
# 00:5B:83  1
# 0c:6E:9D  1
# 00:CC:41  1
# 0c:5E:4E  1
# 00:30:DC  1
# 08:0B:E5  1
# 0c:35:B7  1
# 04:1B:B3  1
# 08:0C:22  1
# 0c:27:F4  1
# 00:EE:57  1
# 04:0D:33  1
# 04:91:43  1
# 00:C6:6E  1
# 04:61:49  1
# 04:A8:D5  1
# 0c:08:9C  1
# 00:05:5C  1
# 00:26:9D  1
# 04:DB:CB  1
# 0c:C1:1E  1
# 00:49:C5  1
# 0c:63:5F  1
# 00:ED:00  1
# 08:CF:B6  1
# 08:82:10  1
# 08:EA:B6  1
# 04:CD:49  1
# 0c:C0:8E  1
# 00:C8:D0  1
# 00:E2:B3  1
# 08:9C:89  1
# 08:02:A2  1
# 08:C8:E0  1
# 04:7E:F9  1
# 04:B6:DE  1
# 00:C2:A7  1
# 08:33:56  1
# 00:F9:37  1
# 00:0F:26  1
# 04:BA:76  1
# 08:93:ED  1
# 04:8D:34  1
# 0c:22:9B  1
# 04:30:7A  1
# 08:0A:0E  1
# 08:E6:F2  1
# 00:7D:95  1
# 08:3C:A7  1
# 00:2A:1B  1
# 08:06:89  1
# 0c:E7:C9  1
# 0c:4A:85  1
# 04:CA:49  1
# 0c:5B:35  1
# 0c:93:79  1
# 00:5C:DA  1
# 0c:51:B1  1
# 08:A6:2F  1
# 04:72:D4  1
# 04:00:4E  1
# 04:17:F7  1
# 08:F5:49  1
# 04:4A:19  1
# 08:69:C2  1
# 04:52:F9  1
# 00:91:97  1
# 04:07:CB  1
# 00:42:47  1
# 0c:93:8A  1

# %%
device_oui_report.sort_values(by="address")
# Out:
#                     device_name                      device_type  \
# 9           00A05020BEF01B28z22                  Battery Service
# 112         00A05020E1B20028z02                  Battery Service
# 222                    G-519C9C                             None
# 120              Micro Mechanic                             None
# 100              MSH317_Ble_C7A                CUBE TECHNOLOGIES
# 260                        None                        Microsoft
# 140                        None      Hewlett-Packard Company, HP
# 79          00A05020E1A50D200T0                  Battery Service
# 155                        None                        Microsoft
# 196                        None                        Microsoft
# 171                        None                        Microsoft
# 246                        None                        Microsoft
# 136                        None                        Microsoft
# 162                        None                        Microsoft
# 261                        None                        Microsoft
# 135                        None                        Microsoft
# 242                        None                        Microsoft
# 82                         None                        Microsoft
# 164                        None                        Microsoft
# 197                        None                        Microsoft
# 225                        None                             None
# 24                         None                        Microsoft
# 1                          None                   Airplay, Apple
# 198                        None                        Microsoft
# 157                        None                   Apple, Airdrop
# 98                         None                        Microsoft
# 169                        None                        Microsoft
# 160                        None                        Microsoft
# 6                          None                        Microsoft
# 201                        None                        Microsoft
# 192                        None                        Microsoft
# 186                        None                        Microsoft
# 234                        None                        Microsoft
# 211                        None                        Microsoft
# 279                        None                   Airplay, Apple
# 193                        None                        Microsoft
# 265                        None                        Microsoft
# 92                         None                             None
# 182                        None                   Airplay, Apple
# 107                        None                        Microsoft
# 281                        None                        Microsoft
# 94                         None                        Microsoft
# 189                        None                        Microsoft
# 178                        None                        Microsoft
# 18                         None                        Microsoft
# 104                        None                        Microsoft
# 170                        None                        Microsoft
# 245                        None                        Microsoft
# 151                        None                    Apple, Nearby
# 84                         None                        Microsoft
# 51                         None                    Apple, Nearby
# 217                        None                          iBeacon
# 256                        None                    Apple, Nearby
# 166                        None                    Apple, Nearby
# 212                        None              Samsung Electronics
# 48                         None                    Apple, Nearby
# 118                        None                    Apple, Nearby
# 134                        None                    Apple, Nearby
# 60                         None                             None
# 95                         None                    Apple, Nearby
# 11                         None                   Apple, Handoff
# 68                         None                    Apple, Nearby
# 176                        None                    Apple, Nearby
# 12                         None                   Apple, Handoff
# 243                        None                    Apple, Nearby
# 101                        None               Google, Chromecast
# 3                          None                    Apple, Nearby
# 215                        None                    Apple, Nearby
# 96                         None                    Apple, Nearby
# 180                        None                    Apple, Nearby
# 50                         None                    Apple, Nearby
# 53                         None                    Apple, Nearby
# 141                        None               Google, Chromecast
# 88                         None    Smart TV, Samsung Electronics
# 99                         None    Smart TV, Samsung Electronics
# 226                        None                   Apple, Handoff
# 244                        None                    Apple, Nearby
# 224                        None                   Apple, Handoff
# 137                        None                    Apple, Nearby
# 75                         None                    Apple, Nearby
# 122                        None                    Apple, Nearby
# 223                        None                    Apple, Nearby
# 97                         None                        Microsoft
# 264                        None                    Apple, Nearby
# 46                         None                    Apple, Nearby
# 249                        None                    Apple, Nearby
# 36                         None                    Apple, Nearby
# 55                         None                    Apple, Nearby
# 250                        None                    Apple, Nearby
# 255                        None                    Apple, Nearby
# 203                        None                    Apple, Nearby
# 272                        None                    Apple, Nearby
# 65                         None                    Apple, Nearby
# 202                        None                    Apple, Nearby
# 71                         None                    Apple, Nearby
# 238                        None                    Apple, Nearby
# 235                        None                    Apple, Nearby
# 144                        None                             Sony
# 125                        None                    Apple, Nearby
# 31                         None                    Apple, Nearby
# 42                         None                    Apple, Nearby
# 148                        None                    Apple, Nearby
# 37                         None                    Apple, Nearby
# 207                        None                    Apple, Nearby
# 181                        None                    Apple, Nearby
# 113                        None                   Apple, Handoff
# 33                         None                    Apple, Nearby
# 220                        None                    Apple, Nearby
# 204                        None                    Apple, Nearby
# 163                        None                    Apple, Nearby
# 239                        None                    Apple, Nearby
# 72                         None                           Google
# 62                         None                    Apple, Nearby
# 227                        None                    Apple, Nearby
# 165                        None                        Microsoft
# 70                         None                    Apple, Nearby
# 39                         None                   Apple, Handoff
# 216                        None                    Apple, Nearby
# 41                         None                    Apple, Nearby
# 90                         None                    Apple, Nearby
# 40                         None                    Apple, Nearby
# 183                        None                    Apple, Nearby
# 73                         None                   Apple, Handoff
# 190                        None                    Apple, Nearby
# 233                        None                    Apple, Nearby
# 154                        None                    Apple, Nearby
# 45                         None                    Apple, Nearby
# 184                        None                    Apple, Nearby
# 252                        None                    Apple, Nearby
# 254                        None                    Apple, Nearby
# 43                         None                    Apple, Nearby
# 149                        None                        Microsoft
# 23                         None                    Apple, Nearby
# 2                          None                   Apple, Handoff
# 191                        None                    Apple, Nearby
# 64                         None                    Apple, Nearby
# 103                        None                    Apple, Nearby
# 44                         None                    Apple, Nearby
# 58                         None                    Apple, Nearby
# 230                        None                    Apple, Nearby
# 179                        None               Google, Chromecast
# 277                        None                    Apple, Nearby
# 267                        None                    Apple, Nearby
# 59                         None                    Apple, Nearby
# 258                        None                    Apple, Nearby
# 153                        None                   Apple, Handoff
# 57                         None                    Apple, Nearby
# 14                         None                    Apple, Nearby
# 263                        None                    Apple, Nearby
# 236                        None                    Apple, Nearby
# 32                         None                    Apple, Nearby
# 4                          None                    Apple, Nearby
# 259                        None                    Apple, Nearby
# 80                         None                    Apple, Nearby
# 22                         None                    Apple, Nearby
# 34                         None                    Apple, Nearby
# 30                         None             Eddystone UID beacon
# 52                         None                    Apple, Nearby
# 69                         None                    Apple, Nearby
# 47                         None                    Apple, Nearby
# 270                        None                    Apple, Nearby
# 38                         None               Apple, Apple Watch
# 67                         None                   Apple, Handoff
# 83                         None                        Microsoft
# 275                        None                    Apple, Nearby
# 177                        None               Google, Chromecast
# 161                        None                    Apple, Nearby
# 146                        None                    Apple, Nearby
# 132                        None                    Apple, Nearby
# 208                        None                    Apple, Nearby
# 116                        None                    Apple, Nearby
# 210                        None                    Apple, Nearby
# 241                        None                    Apple, Nearby
# 61                         None                    Apple, Nearby
# 27                         None                        Microsoft
# 138                        None                    Apple, Nearby
# 133                        None                    Apple, Nearby
# 167                        None                    Apple, Nearby
# 209                        None                    Apple, Nearby
# 214                        None                    Apple, Nearby
# 271                        None    Smart TV, Samsung Electronics
# 143  [TV] Samsung 6 Series (55)    Smart TV, Samsung Electronics
# 109  [TV] Samsung 6 Series (65)    Smart TV, Samsung Electronics
# 187                        None                        Microsoft
# 247                        None                    Apple, Nearby
# 63                         None                    Apple, Nearby
# 127                        None                    Apple, Nearby
# 110                        None                    Apple, Nearby
# 175                        None                    Apple, Nearby
# 159                        None                    Apple, Nearby
# 269                        None                    Apple, Nearby
# 13                         None                    Apple, Nearby
# 206                        None                    Apple, Nearby
# 145                        None                    Apple, Nearby
# 126                        None                    Apple, Nearby
# 10                         None                    Apple, Nearby
# 54                         None                    Apple, Nearby
# 102                        None               Apple, Touch Setup
# 21                         None                    Apple, Nearby
# 121                        None                    Apple, Nearby
# 26                         None                   Apple, Handoff
# 15                         None                    Apple, Nearby
# 91                         None                    Apple, Nearby
# 232                        None                    Apple, Nearby
# 156                        None               Apple, Touch Setup
# 229                        None                    Apple, Nearby
# 237                        None                    Apple, Nearby
# 278                        None                        Microsoft
# 218                        None                    Apple, Nearby
# 87                         None                    Apple, Nearby
# 19                         None                    Apple, Nearby
# 66                         None                    Apple, Nearby
# 150                        None               Google, Chromecast
# 29                         None                    Apple, Nearby
# 77                         None                    Apple, Nearby
# 108                        None                    Apple, Nearby
# 219                        None                             Sony
# 262                        None                    Apple, Nearby
# 240                        None                    Apple, Nearby
# 131                        None                    Apple, Nearby
# 257                        None                    Apple, Nearby
# 200                        None                    Apple, Nearby
# 106                        None                    Apple, Nearby
# 114                        None                    Apple, Nearby
# 93                         None                    Apple, Nearby
# 194                        None                    Apple, Nearby
# 248                 Dispatch TV                           Google
# 152                        None                    Apple, Nearby
# 251                        None                    Apple, Nearby
# 119                        None                    Apple, Nearby
# 266                        None                    Apple, Nearby
# 124                        None                    Apple, Nearby
# 273                        None                    Apple, Nearby
# 147                        None                    Apple, Nearby
# 185                        None                    Apple, Nearby
# 85                         None                    Apple, Nearby
# 276                        None               Google, Chromecast
# 213                        None                    Apple, Nearby
# 105                        None                   Apple, Handoff
# 78                         None                    Apple, Nearby
# 81                         None                    Apple, Nearby
# 74                         None                    Apple, Nearby
# 35                         None                    Apple, Nearby
# 253                        None                    Apple, Nearby
# 49                         None                           Google
# 20                         None                    Apple, Nearby
# 56                         None                    Apple, Nearby
# 139                        None                    Apple, Nearby
# 123                        None                    Apple, Nearby
# 86                         None                    Apple, Nearby
# 0                          None               Google, Chromecast
# 117                        None                    Apple, Nearby
# 221                        None                    Apple, Nearby
# 16                         None                    Apple, Nearby
# 172                        None                    Apple, Nearby
# 158                        None                   Apple, Handoff
# 173                        None                    Apple, Nearby
# 168                        None                    Apple, Nearby
# 188                        None                    Apple, Nearby
# 231                        None            Apple, Wireless Audio
# 25           MediaPlayer-830761                             None
# 5                          None                             None
# 268                        None    Smart TV, Samsung Electronics
# 7                          None      Hewlett-Packard Company, HP
# 142             DCS-8525LH-4270                             None
# 195            ALAM (24:F7:2C)                             None
# 17                   JBL Flip 3  Harman International Industries
# 228             DV7200-4.0-382C                             None
# 199              Forerunner 25                           Garmin
# 76                         None                            Apple
# 130                        None                    Apple, Nearby
# 115                    PDSCB110                             None
# 8                        iRadar                 nRF UART Service
# 128                        None    Smart TV, Samsung Electronics
# 274                        None                            Apple
# 89                         None                            Apple
# 205                        None                            Apple
# 28                         None                            Apple
# 280  [TV] Samsung 7 Series (65)    Smart TV, Samsung Electronics
# 174                        None    Smart TV, Samsung Electronics
# 129                        None    Smart TV, Samsung Electronics
# 111                        None                            Apple
#
#                address                         service_uuids
# 9    00:01:AD:66:08:66                                  180f
# 112  00:01:AD:71:87:09                                  180f
# 222  00:05:C2:51:9C:9C  47726f74-6547-4c4f-5353-414253000000
# 120  00:1D:A5:00:F9:57                                  fff0
# 100  00:22:6C:D6:8C:7B                             ffc0,6666
# 260  00:26:9D:67:3A:1F                                  None
# 140  00:68:EB:FB:22:E3                                  fe78
# 79   00:A0:50:20:E1:A5                                  180f
# 155  08:02:A2:3A:43:01                                  None
# 196  08:B3:D8:50:91:21                                  None
# 171  08:C8:E0:8B:31:73                                  None
# 246  0C:5E:4E:7A:0E:FB                                  None
# 136  0C:8F:D5:E3:19:0B                                  None
# 162  0C:E5:23:B9:8F:71                                  None
# 261  0C:E7:C9:BE:65:02                                  None
# 135  10:91:97:59:FF:39                                  None
# 242  10:C0:D2:68:7D:EA                                  None
# 82   10:C2:A7:8C:73:7D                                  None
# 164  10:EB:D1:4A:EF:C6                                  None
# 197  18:2D:37:5B:4B:DD                                  None
# 225  18:EB:77:A2:61:71                                  None
# 24   1C:61:4C:F2:B6:E3                                  None
for old_msd in list(old_msds):
    new_msds = new_msds[new_msds.msd_key != old_msd]

msd_table = pd.DataFrame(new_msds.msd_key.value_counts())

# Convert msd_key into hex
msd_counts = list()

for msd_key in msd_table.index:
    msd_counts.append(['0x{:02x}'.format(int(float(msd_key))),msd_key, msd_table.loc[msd_key, "msd_key"]])

msd_counts = pd.DataFrame(msd_counts)
msd_counts.columns = ["Manufacturer ID (hex)", "Manufacturer ID (raw)", "Count"]

device_report = list()

for new_msd in msd_counts["Manufacturer ID (raw)"]:
    new_device = new_devices[new_devices.msd_key == new_msd]
    
    for device in new_device.index:
        device_report.append(new_device.loc[device, ["device_name", "device_type", "address", "service_uuids", "msd_key"]].values)

device_msd_report = pd.DataFrame(device_report)
device_msd_report.columns = ["device_name", "device_type", "address", "service_uuids", "Manufacturer ID (raw)"]

# %%
msd_counts
# Out:
#   Manufacturer ID (hex)  Manufacturer ID (raw)  Count
# 0                0x7544                30020.0      2
# 1                 0x5c7                 1479.0      1
# 2                0x3141                12609.0      1
# 3                0xa212                41490.0      1
# 4                 0x1a5                  421.0      1

# %%
device_msd_report.sort_values(by="address")
# Out:
#           device_name              device_type            address  \
# 0          Dual iPlug                     None  21:E1:63:A3:42:41
# 1          Dual iPlug                     None  41:42:D3:BB:C2:14
# 4                None                     None  88:D0:39:98:C7:E4
# 3     DCS-8525LH-4270                     None  B0:C5:54:50:42:70
# 5                I_TL  Icon Health and Fitness  DA:5D:5A:48:68:17
# 2  LCIRemoteNwBKfKvbV       Lippert Components  F3:FE:46:53:CA:8F
#
#                           service_uuids  Manufacturer ID (raw)
# 0                                  None                30020.0
# 1                                  None                30020.0
# 4                                  None                41490.0
# 3  3910bf96-4348-f3e4-a002-6afb7fc989ae                12609.0
# 5  00001533-1412-efde-1523-785feabcd123                  421.0
# 2  00000000-0200-a58e-e411-afe28044e62c                 1479.0

# %% [markdown]
# ## New Service UUIDs

# %%
old_uuids = old_devices['service_uuids'].dropna(how='any').unique()

new_uuids = new_devices.copy()
for old_uuid in old_uuids:
    new_uuids = new_uuids[new_uuids.service_uuids != old_uuid]

device_report = list()

for new_msd in msd_counts["Manufacturer ID (raw)"]:
    new_device = new_devices[new_devices.msd_key == new_msd]
    
    for device in new_device.index:
        device_report.append(new_device.loc[device, ["device_name", "device_type", "address", "service_uuids", "msd_key"]].values)

device_msd_report = pd.DataFrame(device_report)
device_msd_report.columns = ["device_name", "device_type", "address", "service_uuids", "Manufacturer ID (raw)"]

uuid_count = pd.DataFrame(new_uuids.service_uuids.value_counts()).sort_index()

device_report = list()

for new_uuid in uuid_count.index:
    new_device = new_devices[new_devices.service_uuids == new_uuid]
    
    for device in new_device.index:
        device_report.append(new_device.loc[device, ["device_name", "device_type", "address", "service_uuids"]].values)

device_uuid_report = pd.DataFrame(device_report)
device_uuid_report.columns = ["device_name", "device_type", "address", "service_uuids"]

# %%
uuid_count
# Out:
#                                            service_uuids
# 0000                                                   1
# 00000000-0200-a58e-e411-afe28044e62c                   1
# 00001533-1412-efde-1523-785feabcd123                   1
# 3910bf96-4348-f3e4-a002-6afb7fc989ae                   1
# 447c0000-ed49-fe29-71e1-87a4e15ecff6                   1
# 47726f74-6547-4c4f-5353-414253000000                   1
# 6e400001-b5a3-f393-e0a9-e50e24dcca9e                   1
# 88e0                                                   1
# fd6f                                                   1
# feaa,1786b941-062b-17b7-4df6-3f79361ad91f              1
# fef5,e8d84b30-785f-0000-0000-0401f4ac4ea4              1
# ffc0,6666                                              1

# %%
device_uuid_report.sort_values(by="address")
# Out:
#            device_name                                        device_type  \
# 5             G-519C9C                                               None
# 11      MSH317_Ble_C7A                                  CUBE TECHNOLOGIES
# 7              Mercury                                               None
# 8                 None                              Exposure Notification
# 3      DCS-8525LH-4270                                               None
# 4             PDSCB110                                               None
# 6               iRadar                                   nRF UART Service
# 2                 I_TL                            Icon Health and Fitness
# 9                 None  iBeacon, Eddystone URL beacon - http://mrefer....
# 10                XY4+                      iBeacon, Dialog Semiconductor
# 1   LCIRemoteNwBKfKvbV                                 Lippert Components
# 0     iHome iBTW39 app                                  CUBE TECHNOLOGIES
#
#               address                              service_uuids
# 5   00:05:C2:51:9C:9C       47726f74-6547-4c4f-5353-414253000000
# 11  00:22:6C:D6:8C:7B                                  ffc0,6666
# 7   0A:F9:0A:41:05:00                                       88e0
# 8   35:BE:AB:BF:94:69                                       fd6f
# 3   B0:C5:54:50:42:70       3910bf96-4348-f3e4-a002-6afb7fc989ae
# 4   D0:C5:D3:EF:55:BE       447c0000-ed49-fe29-71e1-87a4e15ecff6
# 6   D0:C6:6E:BD:5D:39       6e400001-b5a3-f393-e0a9-e50e24dcca9e
# 2   DA:5D:5A:48:68:17       00001533-1412-efde-1523-785feabcd123
# 9   E2:7A:82:7A:9E:DF  feaa,1786b941-062b-17b7-4df6-3f79361ad91f
# 10  E9:12:1D:F1:C3:0E  fef5,e8d84b30-785f-0000-0000-0401f4ac4ea4
# 1   F3:FE:46:53:CA:8F       00000000-0200-a58e-e411-afe28044e62c
# 0   F7:EB:ED:DF:4E:91                                       0000

# %% [markdown]
# # Dump Data

# %%
total_devices = pd.read_sql_query("SELECT * from devices", db)

device_names = pd.DataFrame(total_devices.device_name.value_counts()).sort_index()
device_names.columns = ["Count"]
device_names.to_csv('device_names.csv', index_label='Device Name')
device_names.index.names = ["Top Device Names"]

device_types = pd.DataFrame(total_devices.device_type.value_counts()).sort_index()
device_types.columns = ["Count"]
device_types.to_csv('device_types.csv', index_label='Device Type')
device_types.index.names = ["Top Device Types"]

print(f"Exported {device_names.count()[0]} device names to `device_names.csv`")
print(f"Exported {device_types.count()[0]} device names to `device_types.csv`")
# Out:
# Exported 537 device names to `device_names.csv`
# Exported 122 device names to `device_types.csv`

# %% [markdown]
# ## Count by Device Name

# %%
device_names.sort_values(by="Count", ascending=False).head()
# Out:
#                            Count
# Top Device Names
# Tile                         104
# Charge 2                      32
# Versa                         23
# H                             16
# Apple Pencil     15

# %% [markdown]
# ## Count by Device Types

# %%
device_types.sort_values(by="Count", ascending=False).head()
# Out:
#                   Count
# Top Device Types
# Apple, Nearby      6043
# Microsoft          1716
# iBeacon            1120
# Apple, Handoff      575
# Google              348
