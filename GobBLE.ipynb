# %% [markdown]
# Setup globals

# %%
import datetime
import gmaps
import gmaps.datasets
import math
import os.path
import pandas as pd
import sqlite3
import time
from IPython.display import display, Markdown

day_of_seconds = 86400
week_of_seconds = 7 * day_of_seconds
month_of_seconds = 30 * day_of_seconds

today = int(time.mktime(datetime.date.today().timetuple()))

# %% [markdown]
# The following cell values are safe to modify as needed

# %%
sqlite_file = 'RaMBLE.sqlite'
gmaps_apikey_filename = 'gmaps_api.key'
max_rows = 500
gmaps

# Typically only looking back the past week
wayback = week_of_seconds

# %% [markdown]
# Pull in database

# %%
pd.set_option('display.max_rows', max_rows)
db = sqlite3.connect(sqlite_file)
device_table = pd.read_sql_query("SELECT * from devices", db)
lastest_activity = device_table.last_seen.max()

new_devices = device_table[device_table.first_seen >= lastest_activity-wayback]
old_devices = device_table[device_table.first_seen < lastest_activity-wayback]

# %% [markdown]
# The database has two important tables: `devices` and `locations`
#
# devices
# * id (int)
# * address (string: OUI)
# * adv_flags (float)
# * device_name (string)
# * device_type (string)
# * first_seen (int)
# * last_seen (int)
# * msd_key (float, Manufacturer Data: ID)
# * msd_field (hex string, Manufacturer Data: Data)
# * service_uuids (string uuid)
# * service_data (string hex data)
# * days_seen (int)
# * raw_adv_data (bitstring)
#
# locations
# * id (int)
# * device_id (int)
# * timestamp (int)
# * rssi (int)
# * tx_power (float)
# * latitude (float)
# * logitude (float)
# * accuracy (float)
# * packets_received (int)

# %%
oui_table = pd.read_csv('data/nmap-mac-prefixes', sep='\t', error_bad_lines=False, names=["oui", "vendor"])
cid_table = pd.read_csv('data/cid.csv',  header=0)
msd_table = pd.read_csv('data/bt_msdid.csv')

def grab_org(address, msd):
    oui_octets = address.split(':')[:3]
    mac_type = 'cid'
    org_name = None
    mfg_name = None
    
    # turn off the multicast bit
    oui_octets[0] = '{:02x}'.format(int(oui_octets[0], 16) & 0xfe)
    oui = ''.join(oui_octets).upper()
    
    # check to see if this is a global oui
    if int(oui_octets[0], 16) & 0x2 == 0:
        mac_type = 'oui'
        org_name = oui_table[oui_table.oui == oui].vendor.values
    else:
        org_name = cid_table[cid_table.Assignment == oui]['Organization Name'].values
        
    if len(org_name) > 0:
        org_name = org_name[0]
    else:
        org_name = mac_type+'/'+':'.join(oui_octets)
        
    if math.isnan(msd) is False:
        mfg_name = msd_table[msd_table.Decimal == int(msd)].Company.values
    
        if len(mfg_name) > 0:
            mfg_name = mfg_name[0]
        else:
            mfg_name = int(msd)

    return org_name, mfg_name

def device_data(device_id):
    data = new_device.loc[device_id, extract_columns].values.tolist()

    org_data = grab_org(data[2], data[5])

    days_seen = data[4]
    data = data[:-2]
    data.extend(org_data)
    data.append(days_seen)
    
    return data

old_names = old_devices['device_name'].dropna(how='any').unique()

# Find devices with device types never seen before
new_names = new_devices.copy()
for old_name in old_names:
    new_names = new_names[new_names.device_name != old_name]

# format count table
name_count = new_names.device_name.value_counts()
name_count.name = ''
name_count = pd.DataFrame(name_count).sort_index()
name_count.index.names = ["device_name"]

extract_columns = ["device_name", "device_type", "address", "service_uuids", "days_seen", "msd_key"]
context_columns = ["device_name", "device_type", "address", "service_uuids", "org name", "manufacturer", "days_seen"]

device_report = list()

# grab contextual data on devices and add them to our device report
for new_name in name_count.index:
    new_device = new_devices[new_devices.device_name == new_name]
    
    # Add devices to our report list
    for device_id in new_device.index:
        device_report.append(device_data(device_id))

# Find devices with device types never seen before

old_types = old_devices['device_type'].dropna(how='any').sort_values().unique()
new_types = new_devices.copy()

for old_type in list(old_types):
    new_types = new_types[new_types.device_type != old_type]

# format count table
type_count = new_types.device_type.value_counts()
type_count.name = ''
type_count = pd.DataFrame(type_count).sort_index()
type_count.index.names = ["device_type"]

# Add any of these devices to our device list if we haven't already

for new_type in type_count.index:
    new_device = new_devices[new_devices.device_type == new_type]
    
    for device_id in new_device.index:
        # Check to see if they would have been reported for their name
        if new_device.loc[device_id, "device_name"] in name_count.index:
            continue
        
        # They haven't been reported before, add them
        device_report.append(device_data(device_id))

# Find devices with Service UUIDs never seen before

old_uuids = old_devices['service_uuids'].dropna(how='any').unique()

new_uuids = new_devices.copy()
for old_uuid in old_uuids:
    new_uuids = new_uuids[new_uuids.service_uuids != old_uuid]

# format count table
uuid_count = new_uuids.service_uuids.value_counts()
uuid_count.name = ''
uuid_count = pd.DataFrame(uuid_count).sort_index()
uuid_count.index.names = ["service_uuids"]

# Add any of these devices to our device list if we haven't already

for new_uuid in uuid_count.index:
    new_device = new_devices[new_devices.service_uuids == new_uuid]
    
    for device_id in new_device.index:
        # Check to see if they would have been reported for their name
        if new_device.loc[device_id, "device_name"] in name_count.index:
            continue
        
        # Check to see if they would have been reported for their type
        if new_device.loc[device_id, "device_type"] in type_count.index:
            continue
        
        # They haven't been reported before, add them
        device_report.append(device_data(device_id))

# Turn our list into a dataframe
if len(device_report) > 0:
    device_report = pd.DataFrame(device_report)
    device_report.columns = context_columns
else:
    device_report = pd.DataFrame(columns = context_columns)
    # Dump report to csv
    device_report.to_csv('interesting_devices.csv')

# %%
display(Markdown("# New Devices of Interest"))
display(Markdown(f"{old_devices.id.count()} devices from {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(old_devices.iloc[0].first_seen))} to {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(old_devices.iloc[-1].first_seen))}"))
display(Markdown(f"{new_devices.id.count()} devices from {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(new_devices.iloc[0].first_seen))} to {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(new_devices.iloc[-1].first_seen))}"))
# Out:
# # New Devices of Interest
# 10545 devices from 2018-11-20 15:12:37 to 2020-03-13 17:39:36
# 1156 devices from 2020-08-31 18:06:10 to 2020-09-05 13:31:39

# %%
name_count
# Out:
#
# device_name
# 00A05020BEF01B28z22         1
# 00A05020E1A50D200T0         1
# 00A05020E1B20028z02         1
# ALAM (24:F7:2C)            1
# BLE-OHL-01                  1
# BLE_08A0                    1
# BLE_891B                    1
# BLE_92EB                    1
# BLE_C826                    1
# BLE_E586                    1
# C-by-GE-D238D755            1
# CB833CAE8D48                1
# CCGB617400320               1
# CCJB618380306               1
# DCS-8525LH-4270             1
# DV7200-4.0-382C             1
# Dispatch TV                 1
# Dual iPlug                  2
# ELK-BLEDOM                  4
# Forerunner 25              1
# G-519C9C                    1
# Galaxy Watch (656E) LE      1
# I_TL                        1
# IronSoulCast                1
# JBL Flip 3                  1
# LCIRemoteNwBKfKvbV          1
# LE-Bose SoundSport Free     1
# LG CJ45  (70)               1
# LG CJ45  (83)               1
# LG CJ45  (F1)               1
# LG SH4(6F)                  1
# LG SH4(72)                  1
# MSH317_Ble_C7A              1
# MediaPlayer-830761          1
# Mercury                     1
# Micro Mechanic              1
# Office speaker              4
# PDSCB110                    1
# PayPal-10395335             1
# QHM-0CAE                    1
# RN456D                      1
# SpinTouch-061623            1
# Tag-It                      1
# VM-207-BLE                  1
# XY4+                        1
# [LG] webOS TV UJ6540        2
# [TV] Samsung 6 Series (40)  1
# [TV] UN40JU6500             1
# [TV] UN50JU6500             1
# [TV] UN65J6300              1
# iHome iBTW39 app            1
# iRadar                      1
# ihoment_H6105_6675          1
# ihoment_H6114_7902          1

# %%
type_count
# Out:
#
# device_type
# Apple, Wireless Audio                                4
# Bose                                                 3
# Bose, SGL Italia                                     2
# CSR                                                  1
# CUBE TECHNOLOGIES                                    3
# Device Information                                   6
# Device Information, Fitbit                           1
# Eddystone UID beacon                                 1
# Eddystone URL beacon - http://mrefer.com/415323...   1
# Exposure Notification                                1
# Fitbit Charge, Device Information, Fitbit            1
# Google, Chromecast                                  30
# Hewlett-Packard Company, HP                         11
# Icon Health and Fitness                              1
# Lippert Components                                   1
# ORBCOMM                                              2
# Sony                                                 2
# iBeacon, Dialog Semiconductor                        1
# iBeacon, Eddystone URL beacon - http://mrefer.c...   1

# %%
uuid_count
# Out:
#
# service_uuids
# 0000                                       1
# 00000000-0200-a58e-e411-afe28044e62c       1
# 00001533-1412-efde-1523-785feabcd123       1
# 3910bf96-4348-f3e4-a002-6afb7fc989ae       1
# 447c0000-ed49-fe29-71e1-87a4e15ecff6       1
# 47726f74-6547-4c4f-5353-414253000000       1
# 6e400001-b5a3-f393-e0a9-e50e24dcca9e       1
# 88e0                                       1
# fd6f                                       1
# feaa,1786b941-062b-17b7-4df6-3f79361ad91f  1
# fef5,e8d84b30-785f-0000-0000-0401f4ac4ea4  1
# ffc0,6666                                  1

# %%
if os.path.exists(gmaps_apikey_filename):
    gmaps_api = ''
    
    with open(gmaps_apikey_filename, 'r') as file:
        gmaps_api = file.read().replace('\n', '')
    
    gmaps.configure(api_key=gmaps_api)
    
    locations = pd.read_sql_query("SELECT * from locations", db)
    stationary_devices = device_report[device_report['days_seen'] > 1]
    print("Devices only seen one day")
    display(device_report[device_report['days_seen'] == 1].sort_values(by="address")[context_columns[:-1]])
    
    print("Devices seen multiple days")
    
    for x in range(len(stationary_devices.index)):
        display(stationary_devices.iloc[[x]])
        
        device_ids = new_devices[new_devices.address == stationary_devices.iloc[[x]].address.values[0]].id
        device_locations = locations[locations['device_id'] == device_ids.values[0]][['latitude', 'longitude']]
        device_rssi = locations[locations['device_id'] == device_ids.values[0]][['rssi']]
        
        #display(device_rssi.dtypes)
        weights = list()
        
        for weight in device_rssi.values:
            weights.append(weight+101)

        fig = gmaps.figure()
        fig.add_layer(gmaps.heatmap_layer(device_locations))
        display(fig)
else:
    print()
    display(Markdown("**Location mapping not enabled** To enable heatmaps of stationary devices, save your Google Maps Javascript SDK API Key in the file `gmaps_api.key`"))
    display(device_report.sort_values(by="address"))
# Out:
# **Location mapping not enabled** To enable heatmaps of stationary devices, save your Google Maps Javascript SDK API Key in the file `gmaps_api.key`
#                     device_name  \
# 0           00A05020BEF01B28z22
# 2           00A05020E1B20028z02
# 24                     G-519C9C
# 39               Micro Mechanic
# 45              PayPal-10395335
# 36               MSH317_Ble_C7A
# 116                        None
# 1           00A05020E1A50D200T0
# 118                        None
# 115                        None
# 47                       RN456D
# 31                LG CJ45  (70)
# 33                LG CJ45  (F1)
# 32                LG CJ45  (83)
# 35                   LG SH4(72)
# 34                   LG SH4(6F)
# 38                      Mercury
# 17                   Dual iPlug
# 69   LE-Bose Color II SoundLink
# 68   LE-Bose Color II SoundLink
# 80                         None
# 120                        None
# 83                         None
# 18                   Dual iPlug
# 105                        None
# 101                        None
# 88                         None
# 52         [LG] webOS TV UJ6540
# 123                        None
# 99                         None
# 100                        None
# 66      LE-Bose Free SoundSport
# 67                LE-reserved_C
# 30      LE-Bose SoundSport Free
# 42               Office speaker
# 107                        None
# 104                        None
# 97                         None
# 98                         None
# 102                        None
# 65                         None
# 87                         None
# 94                         None
# 86                         None
# 78                         None
# 89                         None
# 96                         None
# 95                         None
# 84                         None
# 40               Office speaker
# 43               Office speaker
# 41               Office speaker
# 53         [LG] webOS TV UJ6540
# 91                         None
# 90                         None
# 92                         None
# 93                         None
# 124                        None
# 50                   VM-207-BLE
# 103                        None
# 64                         None
# 109                        None
# 16                  Dispatch TV
# 108                        None
# 106                        None
# 4                    BLE-OHL-01
# 57               [TV] UN65J6300
# 27                 IronSoulCast
# 82                         None
# 63                         None
# 85                         None
# 110                        None
# 111                        None
# 37           MediaPlayer-830761
# 121                        None
# 113                        None
# 62                         None
# 10             C-by-GE-D238D755
# 11                 CB833CAE8D48
# 61           ihoment_H6114_7902
# 60           ihoment_H6105_6675
# 46                     QHM-0CAE
# 112                        None
# 14              DCS-8525LH-4270
# 3              ALAM (24:F7:2C)
# 28                   JBL Flip 3
# 48             SpinTouch-061623
# 122                        None
# 22                  ELK-BLEDOM
# 21                  ELK-BLEDOM
# 20                  ELK-BLEDOM
# 19                  ELK-BLEDOM
# 15              DV7200-4.0-382C
# 75                      Versa 2
# 70                         None
# 79                         None
# 23               Forerunner 25
# 44                     PDSCB110
# 59                       iRadar
# 81                     Charge 3
# 12                CCGB617400320
# 76                      Versa 2
# 13                CCJB618380306
# 26                         I_TL
# 125                        None
# 54   [TV] Samsung 6 Series (40)
# 114                        None
# 119                        None
# 51                         XY4+
# 72                      Versa 2
# 25       Galaxy Watch (656E) LE
# 29           LCIRemoteNwBKfKvbV
# 9                      BLE_E586
# 7                      BLE_92EB
# 6                      BLE_891B
# 5                      BLE_08A0
# 8                      BLE_C826
# 58             iHome iBTW39 app
# 56              [TV] UN50JU6500
# 55              [TV] UN40JU6500
# 77                   Inspire HR
# 74                   Versa Lite
# 71                      Versa 2
# 117                        None
# 73                      Versa 2
# 49             Tag-It
#
#                                            device_type            address  \
# 0                                      Battery Service  00:01:AD:66:08:66
# 2                                      Battery Service  00:01:AD:71:87:09
# 24                                                None  00:05:C2:51:9C:9C
# 39                                                None  00:1D:A5:00:F9:57
# 45                                                None  00:1D:FA:20:09:31
# 36                                   CUBE TECHNOLOGIES  00:22:6C:D6:8C:7B
# 116                        Hewlett-Packard Company, HP  00:68:EB:FB:22:E3
# 1                                      Battery Service  00:A0:50:20:E1:A5
# 118                        Hewlett-Packard Company, HP  02:68:EB:45:2C:20
# 115                        Hewlett-Packard Company, HP  02:68:EB:46:80:9B
# 47                                                None  04:91:62:29:45:6D
# 31                                      LG Electronics  08:EF:3B:54:92:70
# 33                                      LG Electronics  08:EF:3B:7B:18:F1
# 32                                      LG Electronics  08:EF:3B:93:E3:83
# 35                                      LG Electronics  08:EF:3B:D9:D9:72
# 34                                      LG Electronics  08:EF:3B:F0:F4:6F
# 38                                                None  0A:F9:0A:41:05:00
# 17                                                None  21:E1:63:A3:42:41
# 69                                    Bose, SGL Italia  28:11:A5:AB:12:E5
# 68                                    Bose, SGL Italia  2C:41:A1:CC:30:E6
# 80                               Exposure Notification  35:BE:AB:BF:94:69
# 120                        Hewlett-Packard Company, HP  3A:22:E2:9E:58:99
# 83                                  Google, Chromecast  40:E2:B3:BD:6B:08
# 18                                                None  41:42:D3:BB:C2:14
# 105                                 Google, Chromecast  42:7F:61:FD:D2:80
# 101                                 Google, Chromecast  43:83:C3:5A:B3:0A
# 88                                  Google, Chromecast  44:52:F9:C6:9D:46
# 52                                      LG Electronics  45:4B:96:25:5C:37
# 123                                               Sony  48:E2:44:74:7D:A6
# 99                                  Google, Chromecast  4A:67:11:CA:8D:D1
# 100                                 Google, Chromecast  4B:5F:55:60:9D:AE
# 66                                                Bose  4C:87:5D:18:59:34
# 67                                                Bose  4C:87:5D:18:7A:F8
# 30                                                Bose  4C:87:5D:63:AB:25
# 42                                              Google  4D:83:24:06:C0:CA
# 107                                 Google, Chromecast  51:67:FC:E1:8A:F6
# 104                                 Google, Chromecast  51:91:11:FE:13:A5
# 97                                  Google, Chromecast  52:74:7A:28:8B:32
# 98                                  Google, Chromecast  54:E8:10:68:55:9F
# 102                                 Google, Chromecast  56:00:4B:10:7E:30
# 65                               Apple, Wireless Audio  57:5C:A7:82:2F:9F
# 87                                  Google, Chromecast  57:E6:FE:4F:BC:79
# 94                                  Google, Chromecast  59:84:6A:F0:6C:7B
# 86                                  Google, Chromecast  5A:AB:C1:78:14:63
# 78                                Eddystone UID beacon  5C:5B:35:8E:6F:7F
# 89                                  Google, Chromecast  5E:92:F4:52:7C:72
# 96                                  Google, Chromecast  60:3F:10:43:C9:47
# 95                                  Google, Chromecast  61:A4:66:87:DC:E9
# 84                                  Google, Chromecast  61:C6:35:F3:DC:FA
# 40                                              Google  62:28:8D:37:CE:B1
# 43                                              Google  63:C8:3D:8A:78:27
# 41                                              Google  66:6E:8A:22:DC:75
# 53                                      LG Electronics  6A:1B:D3:D9:9C:46
# 91                                  Google, Chromecast  6B:2F:BA:30:BA:AA
# 90                                  Google, Chromecast  6D:C1:F7:33:CF:DB
# 92                                  Google, Chromecast  6F:DE:E6:DF:1D:C2
# 93                                  Google, Chromecast  70:37:B4:AA:D7:9C
# 124                                               Sony  70:77:81:AB:9D:C2
# 50                              Human Interface Device  71:72:59:16:C4:C8
# 103                                 Google, Chromecast  71:B2:B3:68:23:54
# 64                               Apple, Wireless Audio  73:17:6E:DC:5B:9A
# 109                                 Google, Chromecast  73:2D:9D:B8:B8:A4
# 16                                              Google  74:21:CB:E3:6D:62
# 108                                 Google, Chromecast  74:C8:36:8E:2B:BA
# 106                                 Google, Chromecast  77:8E:52:B7:70:80
# 4                               Human Interface Device  78:9C:E7:0B:DA:83
# 57              Smart TV, Samsung, Samsung Electronics  78:BD:BC:9A:D6:B4
# 27                                              Google  79:E6:09:BE:6E:AC
# 82                                  Google, Chromecast  7C:21:8F:63:18:B1
# 63                               Apple, Wireless Audio  7C:EF:8E:D1:AF:8B
# 85                                  Google, Chromecast  7E:56:82:5E:53:C8
# 110                                 Google, Chromecast  7E:72:14:97:B0:47
# 111                                 Google, Chromecast  7F:3A:38:C0:AE:44
# 37                                                None  80:30:DC:04:AD:76
# 121                        Hewlett-Packard Company, HP  82:E8:2C:60:CA:E2
# 113                        Hewlett-Packard Company, HP  82:E8:2C:A9:0E:48
# 62                               Apple, Wireless Audio  91:10:92:00:80:A3
# 10                                Telink Semiconductor  A4:C1:38:0B:62:59
# 11                                Telink Semiconductor  A4:C1:38:82:54:27
# 61                                                None  A4:C1:38:9A:79:02
# 60                                                None  A4:C1:38:A8:66:75
# 46                                                None  AE:0B:00:00:0C:AE
# 112                        Hewlett-Packard Company, HP  B0:5C:DA:CA:47:4F
# 14                                                None  B0:C5:54:50:42:70
# 3                                                 None  B8:3A:9D:24:F7:2D
# 28                     Harman International Industries  B8:69:C2:33:54:B4
# 48                                                None  BB:BD:05:06:16:23
# 122                        Hewlett-Packard Company, HP  BE:E9:2F:AD:68:E7
# 22                                                None  BE:FF:20:01:F0:1C
# 21                                                None  BE:FF:2D:D9:62:95
# 20                                                None  BE:FF:80:00:70:C1
# 19                                                None  BE:FF:F7:00:A8:96
# 15                                                None  C0:42:47:03:98:2C
# 75                                  Device Information  C1:5C:EE:D8:09:F4
# 70                                                 CSR  C1:E9:B6:00:1C:DB
# 79   Eddystone URL beacon - http://mrefer.com/41532...  C7:4E:77:81:86:0F
# 23                                              Garmin  C8:93:ED:EC:40:B1
# 44                                                None  D0:C5:D3:EF:55:BE
# 59                                    nRF UART Service  D0:C6:6E:BD:5D:39
# 81           Fitbit Charge, Device Information, Fitbit  D2:A2:EE:B2:59:51
# 103                                       fe9f
# 64                                        None
# 109                                       fe9f
# 16                                        fea0
# 108                                       fe9f
# 106                                       fe9f
# 4                                         1812
# 57                                        None
# 27                                        fea0
# 82                                        fe9f
# 63                                        None
# 85                                        fe9f
# 110                                       fe9f
# 111                                       fe9f
# 37                                        None
# 121                                       fe78
# 113                                       fe78
# 62                                        None
# 10                                        None
# 11                                        None
# 61                                        None
# 60                                        None
# 46                                        None
# 112                                       fe78
# 14        3910bf96-4348-f3e4-a002-6afb7fc989ae
# 3                                         None
# 28                                        None
# 48                                        None
# 122                                       fe78
# 22                                        None
# 21                                        None
# 20                                        None
# 19                                        None
# 15                                        a032
# 75        abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 70                                        None
# 79                                        feaa
# 23        6a4e3e10-667b-11e3-949a-0800200c9a66
# 44        447c0000-ed49-fe29-71e1-87a4e15ecff6
# 59        6e400001-b5a3-f393-e0a9-e50e24dcca9e
# 81        adabfb00-6e7d-4601-bda2-bffaa68956ba
# 12                                        None
# 76        abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 13                                        None
# 26        00001533-1412-efde-1523-785feabcd123
# 125  feaa,1786b941-062b-17b7-4df6-3f79361ad91f
# 54                                        None
# 114                                       fe78
# 119                                       fe78
# 51   fef5,e8d84b30-785f-0000-0000-0401f4ac4ea4
# 72        abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 25                                        None
# 29        00000000-0200-a58e-e411-afe28044e62c
# 9                                         6666
# 7                                         6666
# 6                                         6666
# 5                                         6666
# 8                                         6666
# 58                                        0000
# 56                                        None
# 55                                        None
# 77        adabfb00-6e7d-4601-bda2-bffaa68956ba
# 74        abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 71        abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 117                                       fe78
# 73        abbaff00-e56a-484c-b832-8b17cf6cbfe8
# 49                                        ffe0
#
#                               org name                           manufacturer  \
# 0    Coach Master d.b.a. CMI Worldwide                                   None
# 2    Coach Master d.b.a. CMI Worldwide                            Apple, Inc.
# 24                             Soronti                                   None
# 39                                  WB                                   None
# 45   Fujian LANDI Commercial Equipment                                   None
# 36                          LinkSprite                      CUBE TECHNOLOGIES
# 116                                 HP                Hewlett-Packard Company
# 1                Cypress Semiconductor                                   None
# 118                       cid/02:68:EB                Hewlett-Packard Company
# 115                       cid/02:68:EB                Hewlett-Packard Company
# 47                           Microchip                                   None
# 31                           MCS Logic                      ​​LG Electronics​
# 33                           MCS Logic                      ​​LG Electronics​
# 32                           MCS Logic                      ​​LG Electronics​
# 35                           MCS Logic                      ​​LG Electronics​
# 34                           MCS Logic                      ​​LG Electronics​
# 38                        cid/0a:F9:0A                                   None
# 17                        oui/20:E1:63                                  30020
# 69                                Bose                      SGL Italia S.r.l.
# 68                                Bose                      SGL Italia S.r.l.
# 80                        oui/34:BE:AB                                   None
# 120                       cid/3a:22:E2                Hewlett-Packard Company
# 83                        oui/40:E2:B3                                 Google
# 18                        oui/40:42:D3                                  30020
